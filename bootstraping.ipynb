# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import random

# %%
scores = [12,15,14,10,18,16,14,19,13,17]

simu_means = []

for i in range(1000):
    sample=random.choices(scores,k=len(scores))
    simu_means.append(np.median(sample))

lower=np.quantile(simu_means,0.025)
upper=np.quantile(simu_means,0.975)

sns.displot(simu_means,kde=True)

plt.axvline(lower)
plt.axvline(upper)

# %%
tea = [78,82,80,79,81,77,76,83,80,82]
coffee=[85,90,88,92,87,95,89,91,93,90]

all_scores = tea+coffee

perm = np.random.permutation(all_scores)

# %%
import numpy as np
import matplotlib . pyplot as plt
from scipy import stats
# Generate roughly Normal data
np . random . seed (0)
data = np . random . normal ( loc =0.0 , scale =1.0 , size =150)
# Q-Q plot vs Normal
stats . probplot ( data , dist ='norm', plot = plt )
plt . title ("Q-Q Plot : Data vs Normal ")
plt . show ()
# Q-Q plot vs Exponential
stats . probplot ( data , dist = stats . expon , plot = plt )
plt . title ("Q-Q Plot : Data vs Exponential ")
plt . show ()

# %%
import random
bag1 = [[1 , 2 , 3 , 6 , 6 , 6] ,
[1 , 2 , 3 , 4 , 4 , 6] ,
[1 , 2 , 3 , 3 , 3 , 5]]
bag2 = [[2 , 2 , 3 , 4 , 5 , 6] ,
[3 , 3 , 3 , 4 , 4 , 5] ,
[1 , 1 , 2 , 4 , 5 , 5]]
counts={}
x=random.choice(bag1[0])
y=random.choice(bag2[0])
key=(x,y)
if key not in counts :
    counts [ key ] = 1
else :
    counts[ key ] += 1
counts
# Out:
# {(6, 4): 1}

# %%
def roll_dice(n,seed=123):
    random.seed(seed)
    counts={}
    sucesses=0

    for i in range(n):
        b=random.randint(0,len(bag1)-1)
        x=random.choice(bag1[b])
        y=random.choice(bag2[b])


        if x+y==8:
            sucesses=sucesses+1
            successes += 1
            key = (x , y )
            if key not in counts :
                counts [ key ] = 1
            else :
                counts[ key ] += 1

    


roll_dice(20000)
